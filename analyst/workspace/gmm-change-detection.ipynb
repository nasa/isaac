# %% [markdown]
# # Gaussian Mixture Models (GMM) Change Detection

# %% [markdown]
# ## GMM change detection using artificial sata

# %% [markdown]
# Specify target the target info and the image source

# %% [markdown]
# ## GMM change detection using a pair of Point Clouds

# %%
from gmm.gmm_change_detection import *

input1 = ""  # Empty input1 since we're using artificial data
input2 = ""  # Empty input1 since we're using artificial data
output_directory = "gmm_saved_models"
test = True
visualize = True
verbose = False
n_start = 4
n_disappearances = 0
n_appearances = 3

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose, n_start, n_disappearances, n_appearances)
# Out:
# Fitting Gamma
# Fitting Theta
# Gamma number of Gaussians: 4
# Theta number of Gaussians: 7
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 3
# Clusters associated with disappearances: 0
# Saved to:
#     test_data_t0_1.pk
#     test_data_t1_1.pk

# %% [markdown]
# ### Reuse the previously segmented points to make the process faster

# %%
input1 = "gmm_saved_models/test_data_t0_1.pk"
input2 = "gmm_saved_models/test_data_t1_1.pk"
test = False

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose, n_start, n_disappearances, n_appearances)
# Out:
# Gamma number of Gaussians: 4
# Theta number of Gaussians: 7
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 3
# Clusters associated with disappearances: 0

# %% [markdown]
# ## GMM change detection using raw Robot Point Clouds

# %%
from gmm.gmm_change_detection import *

input1 = "data/groundtruth_20230419_1830_survey_run4.bag"
input2 = "data/groundtruth_20230419_1836_survey_run5.bag"
output_directory = "gmm_saved_models"
test = False
visualize = True
verbose = False

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose)
# Out:
# Fitting Gamma
# Fitting Theta
# Gamma number of Gaussians: 25
# Theta number of Gaussians: 25
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 3
# Clusters associated with disappearances: 3
# Saved to:
#     groundtruth_20230419_1830_survey_run4_1.pk
#     groundtruth_20230419_1836_survey_run5_1.pk

# %% [markdown]
# ### Reuse the previously segmented points to make the process faster

# %%
input1 = "gmm_saved_models/groundtruth_20230419_1830_survey_run4_1.pk"
input2 = "gmm_saved_models/groundtruth_20230419_1836_survey_run5_1.pk"
output_directory = "gmm_saved_models"
test = False
visualize = True
verbose = False

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose)
# Out:
# Gamma number of Gaussians: 25
# Theta number of Gaussians: 25
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 3
# Clusters associated with disappearances: 3

# %% [markdown]
# ## GMM change detection using a 3D Mesh

# %%
from gmm.gmm_change_detection import *

input1 = "data/run5.ply"
input2 = "data/run4.ply"
output_directory = "gmm_saved_models"
test = False
visualize = True
verbose = False

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose)
# Out:
# Fitting Gamma
# Fitting Theta
# Gamma number of Gaussians: 25
# Theta number of Gaussians: 24
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 2
# Clusters associated with disappearances: 2
# Saved to:
#     run5_1.pk
#     run4_1.pk

# %% [markdown]
# ### Reuse the previously segmented points to make the process faster¶

# %%
input1 = "gmm_saved_models/run5_1.pk"
input2 = "gmm_saved_models/run4_1.pk"
output_directory = "gmm_saved_models"
test = False
visualize = True
verbose = False

gmm_change_detection(input1, input2, output_directory, test, visualize, verbose)
# Out:
# Gamma number of Gaussians: 25
# Theta number of Gaussians: 24
#
# CHANGE GAUSSIANS
# ################################
# Clusters associated with appearances: 2
# Clusters associated with disappearances: 2
